# %%
import os

# os.environ["CUDA_VISIBLE_DEVICES"]="-1" 
import tensorflow as tf
import numpy as np

# Set the seed for random operations. 
# This let our experiments to be reproducible. 
SEED = 1234
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
from os import listdir, makedirs
from os.path import isfile, join, basename, splitext
from random import seed, shuffle
cwd = os.getcwd()


import time
from matplotlib import cm
import matplotlib.pyplot as plt

# %matplotlib inline

# Assign a color to each class
evenly_spaced_interval = np.linspace(0, 1, num_classes)
colors = [cm.rainbow(x) for x in evenly_spaced_interval]

iterator = iter(valid_dataset)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !unzip /content/drive/My\ Drive/Dataset.zip

# %%
# %%capture
# !unzip /content/drive/My\ Drive/file.zip

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

apply_data_augmentation = True

if apply_data_augmentation:
    img_data_gen = ImageDataGenerator(rotation_range=0.2,
                                      width_shift_range=0.05,
                                      height_shift_range=0.05,
                                      shear_range=0.05,
                                      zoom_range=0.05,
                                      horizontal_flip=True,
                                      vertical_flip=True,
                                      fill_mode='reflect')
    mask_data_gen = ImageDataGenerator(rotation_range=0.2,
                                      width_shift_range=0.05,
                                      height_shift_range=0.05,
                                      shear_range=0.05,
                                      zoom_range=0.05,
                                       horizontal_flip=True,
                                       vertical_flip=True,
                                       fill_mode='reflect')
else:
    img_data_gen = ImageDataGenerator()
    mask_data_gen = ImageDataGenerator()

# %%
def read_rgb_mask(img_path):
    '''
    img_path: path to the mask file
    Returns the numpy array containing target values
    '''

    mask_img = Image.open(img_path)
    mask_arr = np.array(mask_img)

    new_mask_arr = np.zeros(mask_arr.shape[:2], dtype=mask_arr.dtype)

    # Use RGB dictionary in 'RGBtoTarget.txt' to convert RGB to target
    new_mask_arr[np.where(np.all(mask_arr == [216, 124, 18], axis=-1))] = 0
    new_mask_arr[np.where(np.all(mask_arr == [255, 255, 255], axis=-1))] = 1
    new_mask_arr[np.where(np.all(mask_arr == [216, 67, 82], axis=-1))] = 2

    return new_mask_arr

# %%
from os import listdir, makedirs
from os.path import isfile, join, basename, splitext
from random import seed, shuffle


def split_dataset(training_dir, split_dir, training_percentage=0.90):
    """
    Starting from a training directory, creates a split directory
    with two text files, enumerating the images present in the 
    training and the validation set. 
    """

    seed(1234)

    file_names = [f for f in listdir(training_dir) if isfile(join(training_dir, f))]
    shuffle(file_names)

    split = int(len(file_names)*training_percentage)
    train_file_names = " \n".join([basename(f) for f in file_names[:split]])
    valid_file_names = " \n".join([basename(f) for f in file_names[split:]])

    makedirs(split_dir)
    with open(join(split_dir, './train.txt'), 'w') as train:
        train.write(train_file_names)
    with open(join(split_dir, './valid.txt'), 'w') as valid:
        valid.write(valid_file_names)


dataset_dir = os.path.join("/content/Development_Dataset/Training/Pead/Haricot/")
split_dataset(join(dataset_dir, 'Images'), join(dataset_dir, 'Splits'))

# %%
from PIL import Image

img_h = 640 
img_w = 640

class CustomDataset(tf.keras.utils.Sequence):

 

  def __init__(self, dataset_dir, which_subset, img_generator=None, mask_generator=None, 
               preprocessing_function=None, out_shape=[img_w, img_h]):
    if which_subset == 'training':
      subset_file = os.path.join(dataset_dir, 'Splits', 'train.txt')
    elif which_subset == 'validation':
      subset_file = os.path.join(dataset_dir, 'Splits', 'valid.txt')
    
    with open(subset_file, 'r') as f:
      lines = f.readlines()
    
    subset_filenames = []
    for line in lines:
      subset_filenames.append(line.strip()) 

    self.which_subset = which_subset
    self.dataset_dir = dataset_dir
    self.subset_filenames = subset_filenames
    self.img_generator = img_generator
    self.mask_generator = mask_generator
    self.preprocessing_function = preprocessing_function
    self.out_shape = out_shape

  def __len__(self):
    return len(self.subset_filenames)

  def __getitem__(self, index):
    # Read Image
    curr_filename = self.subset_filenames[index]
    img = Image.open(os.path.join(self.dataset_dir, 'Images/', curr_filename ))
    if(os.path.isfile(os.path.join(self.dataset_dir, 'Masks/', curr_filename ))):
      mask = Image.fromarray(read_rgb_mask(os.path.join(self.dataset_dir, 'Masks/', curr_filename )))
    else:
      mask = Image.fromarray(read_rgb_mask(os.path.join(self.dataset_dir, 'Masks/', curr_filename.replace(".jpg","")+".png" )))
    # Resize image and mask
    img = img.resize(self.out_shape)
    mask = mask.resize(self.out_shape, resample=Image.NEAREST)
    img_arr = np.array(img)
    mask_arr = np.array(mask)



    mask_arr = np.expand_dims(mask_arr, -1)

    if self.which_subset == 'training':
      if self.img_generator is not None and self.mask_generator is not None:
        img_t = self.img_generator.get_random_transform(img_arr.shape, seed=SEED)
        mask_t = self.mask_generator.get_random_transform(mask_arr.shape, seed=SEED)
        img_arr = self.img_generator.apply_transform(img_arr, img_t)
        out_mask = np.zeros_like(mask_arr)
        for c in np.unique(mask_arr):
          if c > 0:
            curr_class_arr = np.float32(mask_arr == c)
            curr_class_arr = self.mask_generator.apply_transform(curr_class_arr, mask_t)
            # from [0, 1] to {0, 1}
            curr_class_arr = np.uint8(curr_class_arr)
            # recover original class
            curr_class_arr = curr_class_arr * c 
            out_mask += curr_class_arr
    else:
      out_mask = mask_arr
    
    if self.preprocessing_function is not None:
        img_arr = self.preprocessing_function(img_arr)

    return img_arr, np.float32(out_mask)

# %%
from tensorflow.keras.applications.vgg16 import preprocess_input 
import os


num_classes = 3



# Set preprocess_input = None to display original image
dataset = CustomDataset(dataset_dir, 'training', 
                        img_generator=img_data_gen, mask_generator=mask_data_gen)
                        #preprocessing_function=preprocess_input)
dataset_valid = CustomDataset(dataset_dir, 'validation') 
                             # preprocessing_function=preprocess_input)

# %%
bs = 2 # batch size try 3

train_dataset = tf.data.Dataset.from_generator(lambda: dataset,
                                               output_types=(tf.float32, tf.float32),
                                               output_shapes=([img_h, img_w, 3], [img_h, img_w, 1]))

train_dataset = train_dataset.batch(bs)

train_dataset = train_dataset.repeat()

valid_dataset = tf.data.Dataset.from_generator(lambda: dataset_valid,
                                               output_types=(tf.float32, tf.float32),
                                               output_shapes=([img_h, img_w, 3], [img_h, img_w, 1]))
valid_dataset = valid_dataset.batch(bs)

valid_dataset = valid_dataset.repeat()

# %%
from tensorflow import keras

def bn_act(x, act=True):
    x = keras.layers.BatchNormalization()(x)
    if act == True:
        x = keras.layers.Activation("relu")(x)
    return x

def conv_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    conv = bn_act(x)
    conv = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides)(conv)
    return conv

def stem(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    conv = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides)(x)
    conv = conv_block(conv, filters, kernel_size=kernel_size, padding=padding, strides=strides)
    
    shortcut = keras.layers.Conv2D(filters, kernel_size=(1, 1), padding=padding, strides=strides)(x)
    shortcut = bn_act(shortcut, act=False)
    
    output = keras.layers.Add()([conv, shortcut])
    return output

def residual_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    res = conv_block(x, filters, kernel_size=kernel_size, padding=padding, strides=strides)
    res = conv_block(res, filters, kernel_size=kernel_size, padding=padding, strides=1)
    
    shortcut = keras.layers.Conv2D(filters, kernel_size=(1, 1), padding=padding, strides=strides)(x)
    shortcut = bn_act(shortcut, act=False)
    
    output = keras.layers.Add()([shortcut, res])
    return output

def upsample_concat_block(x, xskip):
    u = keras.layers.UpSampling2D((2, 2))(x)
    c = keras.layers.Concatenate()([u, xskip])
    return c

# %%
def ResUNet():
    f = [16, 32, 64, 128, 256]
    inputs = keras.layers.Input((img_h, img_w, 3))
    
    ## Encoder
    e0 = inputs
    e1 = stem(e0, f[0])
    e2 = residual_block(e1, f[1], strides=2)
    e3 = residual_block(e2, f[2], strides=2)
    e4 = residual_block(e3, f[3], strides=2)
    e5 = residual_block(e4, f[4], strides=2)
    
    ## Bridge
    b0 = conv_block(e5, f[4], strides=1)
    b1 = conv_block(b0, f[4], strides=1)
    
    ## Decoder
    u1 = upsample_concat_block(b1, e4)
    d1 = residual_block(u1, f[4])
    
    u2 = upsample_concat_block(d1, e3)
    d2 = residual_block(u2, f[3])
    
    u3 = upsample_concat_block(d2, e2)
    d3 = residual_block(u3, f[2])
    
    u4 = upsample_concat_block(d3, e1)
    d4 = residual_block(u4, f[1])
    
    outputs = keras.layers.Conv2D(3, (1, 1), padding="same", activation="softmax")(d4)
    model = keras.models.Model(inputs, outputs)
    return model

# %%
model = ResUNet()
model.load_weights('/content/drive/MyDrive/unet_custom.h5')

# %%
# Optimization params

# Loss
# Sparse Categorical Crossentropy to use integers (mask) instead of one-hot encoded labels
loss = tf.keras.losses.SparseCategoricalCrossentropy() 
# learning rate
lr = 1e-6
optimizer = tf.keras.optimizers.Adam(learning_rate=lr)

# Here we define the intersection over union for each class in the batch.
# Then we compute the final iou as the mean over classes
def meanIoU(y_true, y_pred):
    # get predicted class from softmax
    y_pred = tf.expand_dims(tf.argmax(y_pred, -1), -1)

    per_class_iou = []

    for i in range(1, num_classes): # exclude the background class 0
      # Get prediction and target related to only a single class (i)
      class_pred = tf.cast(tf.where(y_pred == i, 1, 0), tf.float32)
      class_true = tf.cast(tf.where(y_true == i, 1, 0), tf.float32)
      intersection = tf.reduce_sum(class_true * class_pred)
      union = tf.reduce_sum(class_true) + tf.reduce_sum(class_pred) - intersection
    
      iou = (intersection + 1e-7) / (union + 1e-7)
      per_class_iou.append(iou)

    return tf.reduce_mean(per_class_iou)

# Validation metrics
metrics = ['accuracy', meanIoU]
# Compile Model
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %%
import os
from datetime import datetime
callbacks = []
"""cwd = os.getcwd()

exps_dir = os.path.join(cwd, 'drive/My Drive/Keras4/', 'unet')
if not os.path.exists(exps_dir):
    os.makedirs(exps_dir)

now = datetime.now().strftime('%b%d_%H-%M-%S')

model_name = 'unet'

exp_dir = os.path.join(exps_dir, model_name + '_' + str(now))
if not os.path.exists(exp_dir):
    os.makedirs(exp_dir)
    
callbacks = []

# Model checkpoint
# ----------------
ckpt_dir = os.path.join(exp_dir, 'ckpts')
if not os.path.exists(ckpt_dir):
    os.makedirs(ckpt_dir)

ckpt_callback = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(ckpt_dir, 'cp_{epoch:02d}.ckpt'), 
                                                   save_weights_only=True)  # False to save the model directly
callbacks.append(ckpt_callback)

# Visualize Learning on Tensorboard
# ---------------------------------
tb_dir = os.path.join(exp_dir, 'tb_logs')
if not os.path.exists(tb_dir):
    os.makedirs(tb_dir)
    
# By default shows losses and metrics for both training and validation
tb_callback = tf.keras.callbacks.TensorBoard(log_dir=tb_dir,
                                             profile_batch=0,
                                             histogram_freq=0)  # if 1 shows weights histograms
callbacks.append(tb_callback)"""

# Early Stopping
# --------------
early_stop = True
if early_stop:
    es_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=6)
    callbacks.append(es_callback)




# How to visualize Tensorboard

# 1. tensorboard --logdir EXPERIMENTS_DIR --port PORT     <- from terminal
# 2. localhost:PORT   <- in your browser

# %%
model.fit(x=train_dataset,
          epochs=100,  #### set repeat in training dataset
          steps_per_epoch=len(dataset),
          validation_data=valid_dataset,
          validation_steps=len(dataset_valid), 
          callbacks=callbacks)
# Out:
# Epoch 1/100
# 81/81 [==============================] - 213s 3s/step - loss: 1.6485 - accuracy: 0.3634 - meanIoU: 0.0378 - val_loss: 1.3610 - val_accuracy: 0.4706 - val_meanIoU: 0.0479
# Epoch 2/100
# 81/81 [==============================] - 211s 3s/step - loss: 1.4136 - accuracy: 0.3902 - meanIoU: 0.0395 - val_loss: 1.2249 - val_accuracy: 0.4648 - val_meanIoU: 0.0537
# Epoch 3/100
# 81/81 [==============================] - 208s 3s/step - loss: 1.2673 - accuracy: 0.4318 - meanIoU: 0.0480 - val_loss: 1.2209 - val_accuracy: 0.4566 - val_meanIoU: 0.0576
# Epoch 4/100
# 81/81 [==============================] - 208s 3s/step - loss: 1.1610 - accuracy: 0.4774 - meanIoU: 0.0584 - val_loss: 1.2090 - val_accuracy: 0.4644 - val_meanIoU: 0.0648
# Epoch 5/100
# 81/81 [==============================] - 208s 3s/step - loss: 1.0728 - accuracy: 0.5250 - meanIoU: 0.0679 - val_loss: 1.1605 - val_accuracy: 0.4893 - val_meanIoU: 0.0716
# Epoch 6/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.9980 - accuracy: 0.5705 - meanIoU: 0.0771 - val_loss: 1.0877 - val_accuracy: 0.5251 - val_meanIoU: 0.0783
# Epoch 7/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.9328 - accuracy: 0.6131 - meanIoU: 0.0861 - val_loss: 1.0085 - val_accuracy: 0.5659 - val_meanIoU: 0.0858
# Epoch 8/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.8756 - accuracy: 0.6529 - meanIoU: 0.0951 - val_loss: 0.9339 - val_accuracy: 0.6060 - val_meanIoU: 0.0938
# Epoch 9/100
# 81/81 [==============================] - 208s 3s/step - loss: 0.8245 - accuracy: 0.6895 - meanIoU: 0.1060 - val_loss: 0.8671 - val_accuracy: 0.6440 - val_meanIoU: 0.1023
# Epoch 10/100
# 81/81 [==============================] - 206s 3s/step - loss: 0.7813 - accuracy: 0.7217 - meanIoU: 0.1144 - val_loss: 0.8125 - val_accuracy: 0.6778 - val_meanIoU: 0.1111
# Epoch 11/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.7422 - accuracy: 0.7510 - meanIoU: 0.1238 - val_loss: 0.7647 - val_accuracy: 0.7091 - val_meanIoU: 0.1203
# Epoch 12/100
# 81/81 [==============================] - 208s 3s/step - loss: 0.7050 - accuracy: 0.7779 - meanIoU: 0.1359 - val_loss: 0.7208 - val_accuracy: 0.7388 - val_meanIoU: 0.1304
# Epoch 13/100
# 81/81 [==============================] - 208s 3s/step - loss: 0.6723 - accuracy: 0.8010 - meanIoU: 0.1463 - val_loss: 0.6816 - val_accuracy: 0.7657 - val_meanIoU: 0.1409
# Epoch 14/100
# 81/81 [==============================] - 206s 3s/step - loss: 0.6418 - accuracy: 0.8217 - meanIoU: 0.1571 - val_loss: 0.6465 - val_accuracy: 0.7898 - val_meanIoU: 0.1519
# Epoch 15/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.6134 - accuracy: 0.8401 - meanIoU: 0.1674 - val_loss: 0.6153 - val_accuracy: 0.8116 - val_meanIoU: 0.1633
# Epoch 16/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.5872 - accuracy: 0.8562 - meanIoU: 0.1792 - val_loss: 0.5861 - val_accuracy: 0.8315 - val_meanIoU: 0.1753
# Epoch 17/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.5634 - accuracy: 0.8695 - meanIoU: 0.1885 - val_loss: 0.5604 - val_accuracy: 0.8487 - val_meanIoU: 0.1875
# Epoch 18/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.5405 - accuracy: 0.8817 - meanIoU: 0.2005 - val_loss: 0.5357 - val_accuracy: 0.8642 - val_meanIoU: 0.1999
# Epoch 19/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.5192 - accuracy: 0.8922 - meanIoU: 0.2110 - val_loss: 0.5126 - val_accuracy: 0.8784 - val_meanIoU: 0.2130
# Epoch 20/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.4984 - accuracy: 0.9016 - meanIoU: 0.2222 - val_loss: 0.4910 - val_accuracy: 0.8908 - val_meanIoU: 0.2260
# Epoch 21/100
# 81/81 [==============================] - 206s 3s/step - loss: 0.4799 - accuracy: 0.9091 - meanIoU: 0.2303 - val_loss: 0.4721 - val_accuracy: 0.9013 - val_meanIoU: 0.2386
# Epoch 22/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.4618 - accuracy: 0.9160 - meanIoU: 0.2414 - val_loss: 0.4533 - val_accuracy: 0.9109 - val_meanIoU: 0.2515
# Epoch 23/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.4444 - accuracy: 0.9221 - meanIoU: 0.2513 - val_loss: 0.4355 - val_accuracy: 0.9193 - val_meanIoU: 0.2644
# Epoch 24/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.4281 - accuracy: 0.9271 - meanIoU: 0.2600 - val_loss: 0.4188 - val_accuracy: 0.9265 - val_meanIoU: 0.2764
# Epoch 25/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.4129 - accuracy: 0.9315 - meanIoU: 0.2667 - val_loss: 0.4038 - val_accuracy: 0.9326 - val_meanIoU: 0.2878
# Epoch 26/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.3980 - accuracy: 0.9353 - meanIoU: 0.2758 - val_loss: 0.3890 - val_accuracy: 0.9380 - val_meanIoU: 0.2987
# Epoch 27/100
# 81/81 [==============================] - 208s 3s/step - loss: 0.3842 - accuracy: 0.9387 - meanIoU: 0.2813 - val_loss: 0.3756 - val_accuracy: 0.9424 - val_meanIoU: 0.3084
# Epoch 28/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.3707 - accuracy: 0.9417 - meanIoU: 0.2882 - val_loss: 0.3634 - val_accuracy: 0.9461 - val_meanIoU: 0.3175
# Epoch 29/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.3580 - accuracy: 0.9443 - meanIoU: 0.2938 - val_loss: 0.3518 - val_accuracy: 0.9493 - val_meanIoU: 0.3258
# Epoch 30/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.3458 - accuracy: 0.9463 - meanIoU: 0.3018 - val_loss: 0.3397 - val_accuracy: 0.9523 - val_meanIoU: 0.3336
# Epoch 31/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.3341 - accuracy: 0.9485 - meanIoU: 0.3055 - val_loss: 0.3293 - val_accuracy: 0.9546 - val_meanIoU: 0.3404
# Epoch 32/100
# 81/81 [==============================] - 206s 3s/step - loss: 0.3230 - accuracy: 0.9501 - meanIoU: 0.3112 - val_loss: 0.3190 - val_accuracy: 0.9568 - val_meanIoU: 0.3471
# Epoch 33/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.3125 - accuracy: 0.9516 - meanIoU: 0.3163 - val_loss: 0.3088 - val_accuracy: 0.9586 - val_meanIoU: 0.3526
# Epoch 34/100
# 81/81 [==============================] - 208s 3s/step - loss: 0.3024 - accuracy: 0.9529 - meanIoU: 0.3211 - val_loss: 0.2990 - val_accuracy: 0.9601 - val_meanIoU: 0.3575
# Epoch 35/100
# 81/81 [==============================] - 208s 3s/step - loss: 0.2928 - accuracy: 0.9541 - meanIoU: 0.3252 - val_loss: 0.2895 - val_accuracy: 0.9616 - val_meanIoU: 0.3621
# Epoch 36/100
# 81/81 [==============================] - 208s 3s/step - loss: 0.2835 - accuracy: 0.9552 - meanIoU: 0.3276 - val_loss: 0.2805 - val_accuracy: 0.9627 - val_meanIoU: 0.3655
# Epoch 37/100
# 81/81 [==============================] - 208s 3s/step - loss: 0.2748 - accuracy: 0.9561 - meanIoU: 0.3326 - val_loss: 0.2717 - val_accuracy: 0.9637 - val_meanIoU: 0.3687
# Epoch 38/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.2658 - accuracy: 0.9576 - meanIoU: 0.3358 - val_loss: 0.2641 - val_accuracy: 0.9644 - val_meanIoU: 0.3718
# Epoch 39/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.2584 - accuracy: 0.9577 - meanIoU: 0.3390 - val_loss: 0.2561 - val_accuracy: 0.9652 - val_meanIoU: 0.3740
# Epoch 40/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.2506 - accuracy: 0.9586 - meanIoU: 0.3405 - val_loss: 0.2488 - val_accuracy: 0.9657 - val_meanIoU: 0.3761
# Epoch 41/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.2434 - accuracy: 0.9591 - meanIoU: 0.3449 - val_loss: 0.2414 - val_accuracy: 0.9663 - val_meanIoU: 0.3776
# Epoch 42/100
# 81/81 [==============================] - 208s 3s/step - loss: 0.2364 - accuracy: 0.9597 - meanIoU: 0.3474 - val_loss: 0.2344 - val_accuracy: 0.9667 - val_meanIoU: 0.3791
# Epoch 43/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.2294 - accuracy: 0.9605 - meanIoU: 0.3488 - val_loss: 0.2280 - val_accuracy: 0.9672 - val_meanIoU: 0.3806
# Epoch 44/100
# 81/81 [==============================] - 205s 3s/step - loss: 0.2231 - accuracy: 0.9610 - meanIoU: 0.3514 - val_loss: 0.2218 - val_accuracy: 0.9675 - val_meanIoU: 0.3817
# Epoch 45/100
# 81/81 [==============================] - 206s 3s/step - loss: 0.2169 - accuracy: 0.9615 - meanIoU: 0.3539 - val_loss: 0.2159 - val_accuracy: 0.9678 - val_meanIoU: 0.3829
# Epoch 46/100
# 81/81 [==============================] - 209s 3s/step - loss: 0.2112 - accuracy: 0.9619 - meanIoU: 0.3562 - val_loss: 0.2103 - val_accuracy: 0.9680 - val_meanIoU: 0.3839
# Epoch 47/100
# 81/81 [==============================] - 208s 3s/step - loss: 0.2055 - accuracy: 0.9623 - meanIoU: 0.3582 - val_loss: 0.2049 - val_accuracy: 0.9682 - val_meanIoU: 0.3848
# Epoch 48/100
# 81/81 [==============================] - 208s 3s/step - loss: 0.1998 - accuracy: 0.9629 - meanIoU: 0.3619 - val_loss: 0.1997 - val_accuracy: 0.9685 - val_meanIoU: 0.3859
# Epoch 49/100
# 81/81 [==============================] - 209s 3s/step - loss: 0.1951 - accuracy: 0.9631 - meanIoU: 0.3626 - val_loss: 0.1948 - val_accuracy: 0.9687 - val_meanIoU: 0.3867
# Epoch 50/100
# 81/81 [==============================] - 210s 3s/step - loss: 0.1904 - accuracy: 0.9631 - meanIoU: 0.3677 - val_loss: 0.1898 - val_accuracy: 0.9688 - val_meanIoU: 0.3871
# Epoch 51/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.1848 - accuracy: 0.9641 - meanIoU: 0.3695 - val_loss: 0.1853 - val_accuracy: 0.9690 - val_meanIoU: 0.3882
# Epoch 52/100
# 81/81 [==============================] - 206s 3s/step - loss: 0.1808 - accuracy: 0.9641 - meanIoU: 0.3698 - val_loss: 0.1809 - val_accuracy: 0.9691 - val_meanIoU: 0.3890
# Epoch 53/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.1767 - accuracy: 0.9642 - meanIoU: 0.3737 - val_loss: 0.1765 - val_accuracy: 0.9693 - val_meanIoU: 0.3896
# Epoch 54/100
# 81/81 [==============================] - 206s 3s/step - loss: 0.1727 - accuracy: 0.9645 - meanIoU: 0.3759 - val_loss: 0.1723 - val_accuracy: 0.9694 - val_meanIoU: 0.3896
# Epoch 55/100
# 81/81 [==============================] - 205s 3s/step - loss: 0.1687 - accuracy: 0.9648 - meanIoU: 0.3781 - val_loss: 0.1683 - val_accuracy: 0.9694 - val_meanIoU: 0.3899
# Epoch 56/100
# 81/81 [==============================] - 210s 3s/step - loss: 0.1647 - accuracy: 0.9652 - meanIoU: 0.3790 - val_loss: 0.1645 - val_accuracy: 0.9695 - val_meanIoU: 0.3905
# Epoch 57/100
# 81/81 [==============================] - 206s 3s/step - loss: 0.1612 - accuracy: 0.9653 - meanIoU: 0.3826 - val_loss: 0.1608 - val_accuracy: 0.9696 - val_meanIoU: 0.3906
# Epoch 58/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.1576 - accuracy: 0.9657 - meanIoU: 0.3832 - val_loss: 0.1573 - val_accuracy: 0.9697 - val_meanIoU: 0.3909
# Epoch 59/100
# 81/81 [==============================] - 206s 3s/step - loss: 0.1545 - accuracy: 0.9657 - meanIoU: 0.3867 - val_loss: 0.1540 - val_accuracy: 0.9697 - val_meanIoU: 0.3909
# Epoch 60/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.1511 - accuracy: 0.9661 - meanIoU: 0.3893 - val_loss: 0.1507 - val_accuracy: 0.9698 - val_meanIoU: 0.3909
# Epoch 61/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.1479 - accuracy: 0.9663 - meanIoU: 0.3918 - val_loss: 0.1477 - val_accuracy: 0.9698 - val_meanIoU: 0.3911
# Epoch 62/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.1447 - accuracy: 0.9667 - meanIoU: 0.3922 - val_loss: 0.1448 - val_accuracy: 0.9699 - val_meanIoU: 0.3913
# Epoch 63/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.1422 - accuracy: 0.9667 - meanIoU: 0.3956 - val_loss: 0.1420 - val_accuracy: 0.9699 - val_meanIoU: 0.3913
# Epoch 64/100
# 81/81 [==============================] - 206s 3s/step - loss: 0.1393 - accuracy: 0.9670 - meanIoU: 0.3981 - val_loss: 0.1393 - val_accuracy: 0.9700 - val_meanIoU: 0.3914
# Epoch 65/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.1367 - accuracy: 0.9671 - meanIoU: 0.4003 - val_loss: 0.1367 - val_accuracy: 0.9700 - val_meanIoU: 0.3912
# Epoch 66/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.1340 - accuracy: 0.9675 - meanIoU: 0.4008 - val_loss: 0.1343 - val_accuracy: 0.9700 - val_meanIoU: 0.3914
# Epoch 67/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.1317 - accuracy: 0.9675 - meanIoU: 0.4046 - val_loss: 0.1320 - val_accuracy: 0.9700 - val_meanIoU: 0.3913
# Epoch 68/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.1291 - accuracy: 0.9678 - meanIoU: 0.4047 - val_loss: 0.1298 - val_accuracy: 0.9700 - val_meanIoU: 0.3912
# Epoch 69/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.1265 - accuracy: 0.9682 - meanIoU: 0.4073 - val_loss: 0.1278 - val_accuracy: 0.9700 - val_meanIoU: 0.3912
# Epoch 70/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.1244 - accuracy: 0.9684 - meanIoU: 0.4091 - val_loss: 0.1259 - val_accuracy: 0.9701 - val_meanIoU: 0.3914
# Epoch 71/100
# 81/81 [==============================] - 208s 3s/step - loss: 0.1226 - accuracy: 0.9683 - meanIoU: 0.4139 - val_loss: 0.1239 - val_accuracy: 0.9701 - val_meanIoU: 0.3915
# Epoch 72/100
# 81/81 [==============================] - 208s 3s/step - loss: 0.1200 - accuracy: 0.9688 - meanIoU: 0.4143 - val_loss: 0.1221 - val_accuracy: 0.9701 - val_meanIoU: 0.3917
# Epoch 73/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.1181 - accuracy: 0.9689 - meanIoU: 0.4172 - val_loss: 0.1204 - val_accuracy: 0.9701 - val_meanIoU: 0.3917
# Epoch 74/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.1165 - accuracy: 0.9689 - meanIoU: 0.4201 - val_loss: 0.1188 - val_accuracy: 0.9701 - val_meanIoU: 0.3914
# Epoch 75/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.1145 - accuracy: 0.9691 - meanIoU: 0.4237 - val_loss: 0.1172 - val_accuracy: 0.9701 - val_meanIoU: 0.3909
# Epoch 76/100
# 81/81 [==============================] - 208s 3s/step - loss: 0.1129 - accuracy: 0.9692 - meanIoU: 0.4254 - val_loss: 0.1156 - val_accuracy: 0.9700 - val_meanIoU: 0.3905
# Epoch 77/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.1110 - accuracy: 0.9695 - meanIoU: 0.4261 - val_loss: 0.1142 - val_accuracy: 0.9700 - val_meanIoU: 0.3900
# Epoch 78/100
# 81/81 [==============================] - 206s 3s/step - loss: 0.1095 - accuracy: 0.9695 - meanIoU: 0.4303 - val_loss: 0.1128 - val_accuracy: 0.9699 - val_meanIoU: 0.3895
# Epoch 79/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.1069 - accuracy: 0.9702 - meanIoU: 0.4321 - val_loss: 0.1117 - val_accuracy: 0.9699 - val_meanIoU: 0.3895
# Epoch 80/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.1063 - accuracy: 0.9698 - meanIoU: 0.4353 - val_loss: 0.1104 - val_accuracy: 0.9699 - val_meanIoU: 0.3891
# Epoch 81/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.1044 - accuracy: 0.9702 - meanIoU: 0.4360 - val_loss: 0.1093 - val_accuracy: 0.9698 - val_meanIoU: 0.3888
# Epoch 82/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.1032 - accuracy: 0.9702 - meanIoU: 0.4406 - val_loss: 0.1081 - val_accuracy: 0.9698 - val_meanIoU: 0.3887
# Epoch 83/100
# 81/81 [==============================] - 210s 3s/step - loss: 0.1017 - accuracy: 0.9704 - meanIoU: 0.4434 - val_loss: 0.1070 - val_accuracy: 0.9697 - val_meanIoU: 0.3883
# Epoch 84/100
# 81/81 [==============================] - 209s 3s/step - loss: 0.1000 - accuracy: 0.9707 - meanIoU: 0.4437 - val_loss: 0.1060 - val_accuracy: 0.9697 - val_meanIoU: 0.3880
# Epoch 85/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.0987 - accuracy: 0.9708 - meanIoU: 0.4467 - val_loss: 0.1051 - val_accuracy: 0.9696 - val_meanIoU: 0.3874
# Epoch 86/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.0974 - accuracy: 0.9710 - meanIoU: 0.4491 - val_loss: 0.1043 - val_accuracy: 0.9695 - val_meanIoU: 0.3868
# Epoch 87/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.0962 - accuracy: 0.9711 - meanIoU: 0.4516 - val_loss: 0.1035 - val_accuracy: 0.9694 - val_meanIoU: 0.3862
# Epoch 88/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.0949 - accuracy: 0.9713 - meanIoU: 0.4544 - val_loss: 0.1027 - val_accuracy: 0.9693 - val_meanIoU: 0.3857
# Epoch 89/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.0934 - accuracy: 0.9715 - meanIoU: 0.4580 - val_loss: 0.1020 - val_accuracy: 0.9693 - val_meanIoU: 0.3853
# Epoch 90/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.0926 - accuracy: 0.9715 - meanIoU: 0.4596 - val_loss: 0.1013 - val_accuracy: 0.9692 - val_meanIoU: 0.3848
# Epoch 91/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.0919 - accuracy: 0.9714 - meanIoU: 0.4662 - val_loss: 0.1006 - val_accuracy: 0.9691 - val_meanIoU: 0.3841
# Epoch 92/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.0898 - accuracy: 0.9721 - meanIoU: 0.4674 - val_loss: 0.1000 - val_accuracy: 0.9690 - val_meanIoU: 0.3834
# Epoch 93/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.0892 - accuracy: 0.9720 - meanIoU: 0.4688 - val_loss: 0.0995 - val_accuracy: 0.9689 - val_meanIoU: 0.3828
# Epoch 94/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.0885 - accuracy: 0.9720 - meanIoU: 0.4735 - val_loss: 0.0988 - val_accuracy: 0.9689 - val_meanIoU: 0.3825
# Epoch 95/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.0876 - accuracy: 0.9721 - meanIoU: 0.4764 - val_loss: 0.0981 - val_accuracy: 0.9688 - val_meanIoU: 0.3824
# Epoch 96/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.0865 - accuracy: 0.9723 - meanIoU: 0.4794 - val_loss: 0.0974 - val_accuracy: 0.9688 - val_meanIoU: 0.3820
# Epoch 97/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.0854 - accuracy: 0.9725 - meanIoU: 0.4808 - val_loss: 0.0969 - val_accuracy: 0.9688 - val_meanIoU: 0.3816
# Epoch 98/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.0846 - accuracy: 0.9725 - meanIoU: 0.4847 - val_loss: 0.0963 - val_accuracy: 0.9687 - val_meanIoU: 0.3815
# Epoch 99/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.0836 - accuracy: 0.9728 - meanIoU: 0.4856 - val_loss: 0.0958 - val_accuracy: 0.9687 - val_meanIoU: 0.3813
# Epoch 100/100
# 81/81 [==============================] - 207s 3s/step - loss: 0.0829 - accuracy: 0.9728 - meanIoU: 0.4900 - val_loss: 0.0953 - val_accuracy: 0.9687 - val_meanIoU: 0.3811

# %%
model.save('/content/drive/MyDrive/unet_custom.h5')

# %%
iterator = iter(valid_dataset)

# %%
# Show original, correct, predicted (validation)

fig, ax = plt.subplots(1, 3, figsize=(8, 8))
fig.show()
image, target = next(iterator)
print(type(image))
image = image[0]
target = target[0, ..., 0]

out_sigmoid = model.predict(x=tf.expand_dims(image, 0))

predicted_class = tf.argmax(out_sigmoid, -1)

out_sigmoid.shape

predicted_class = predicted_class[0, ...] #256*256
predicted_class.shape

# Assign colors (just for visualization)
target_img = np.zeros([target.shape[0], target.shape[1], 3])
prediction_img = np.zeros([target.shape[0], target.shape[1], 3])

target_img[np.where(target == 0)] = [0, 0, 0]
for i in range(1, num_classes):
  target_img[np.where(target == i)] = np.array(colors[i-1])[:3] * 255

prediction_img[np.where(predicted_class == 0)] = [0, 0, 0]
for i in range(1, num_classes):
  prediction_img[np.where(predicted_class == i)] = np.array(colors[i-1])[:3] * 255

ax[0].imshow(np.uint8(image))
ax[1].imshow(np.uint8(target_img))
ax[2].imshow(np.uint8(prediction_img))

fig.canvas.draw()
# Out:
# <class 'tensorflow.python.framework.ops.EagerTensor'>

# %%
# Compute predictions

from os import listdir
from os.path import isfile, join, basename, splitext

# CustomTestDataset to load test images
# Specify the full path to the folder containing the images
class CustomTestDataset(tf.keras.utils.Sequence):

    def __init__(self, dataset_dir, img_generator=None, 
              preprocessing_function=None, out_shape=[img_h, img_w]):

      subset_filenames = [splitext(basename(f))[0] for f in 
                                                listdir(dataset_dir) if isfile(join(dataset_dir, f))]

      extension = [splitext(basename(f))[1] for f in 
                                                listdir(dataset_dir) if isfile(join(dataset_dir, f))]

      self.dataset_dir = dataset_dir
      self.subset_filenames = subset_filenames
      self.img_generator = img_generator
      self.extension = extension
      self.preprocessing_function = preprocessing_function
      self.out_shape = out_shape


    def __len__(self):
        return len(self.subset_filenames)


    def get_original_size(self, index):
        curr_filename = self.subset_filenames[index]
        img = Image.open(os.path.join(self.dataset_dir, curr_filename + self.extension[index]))
        width, height = img.size

        return [height, width]


    def __getitem__(self, index):
        # Read Image
        curr_filename = self.subset_filenames[index]
        img = Image.open(os.path.join(self.dataset_dir, curr_filename + self.extension[index]))

        # Resize image and mask
        img = img.resize(self.out_shape)
        img_arr = np.array(img)

        if self.preprocessing_function is not None:
            img_arr = self.preprocessing_function(img_arr)

        return img_arr


    def get_name(self, index):
        return self.subset_filenames[index]

# %%
import json
from prepare_submission import rle_encode
test_dir = '/content/Development_Dataset/Test_Dev/'
submission_dict = {}
for dataset in os.listdir(test_dir):
  for plant in os.listdir(os.path.join(test_dir,dataset)):
    directory = os.path.join(test_dir,dataset,plant,"Images")
    test_dataset = CustomTestDataset(directory, preprocessing_function=preprocess_input)
    temp = {}
    for i in range(test_dataset.__len__()):
        image = test_dataset.__getitem__(i)
        img_name = test_dataset.get_name(i)
        original_h, original_w = test_dataset.get_original_size(i)
        prediction = model.predict(tf.expand_dims(image, axis=0))
        mask_arr = tf.argmax(prediction, -1)[0, ...] # (256, 256)
        mask_arr = tf.expand_dims(mask_arr, axis=2)
        print(mask_arr.shape)
        mask_arr = tf.image.resize(mask_arr, (original_h, original_w),                          
                                    method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)

        mask_arr = np.array(mask_arr)

        temp[img_name] = {}
        temp[img_name]['shape'] = [original_h, original_w]
        temp[img_name]['team'] = dataset
        temp[img_name]['crop'] = plant
        temp[img_name]['segmentation'] = {}

        rle_encoded_crop = rle_encode(mask_arr == 1)
        rle_encoded_weed = rle_encode(mask_arr == 2)

        temp[img_name]['segmentation']['crop'] = rle_encoded_crop
        temp[img_name]['segmentation']['weed'] = rle_encoded_weed
      
    submission_dict.update(temp)
with open('/content/drive/MyDrive/submission.json', 'w') as f:
    json.dump(submission_dict, f)
# Out:
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
# (640, 640, 1)
