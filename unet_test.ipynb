# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import os

# os.environ["CUDA_VISIBLE_DEVICES"]="-1" 
import tensorflow as tf
import numpy as np

# Set the seed for random operations. 
# This let our experiments to be reproducible. 
SEED = 1234
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
from os import listdir, makedirs
from os.path import isfile, join, basename, splitext
from random import seed, shuffle
cwd = os.getcwd()
cwd
# Out:
# '/content'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !unzip /content/drive/My\ Drive/Dataset.zip

# %%
# %%capture
# !unzip /content/drive/My\ Drive/file.zip

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

apply_data_augmentation = True

# in case add rescale factor rescale= 1./255,
""" 
    rotation_range=0.2,
    width_shift_range=0.05,
    height_shift_range=0.05,
    shear_range=0.05,
    zoom_range=0.05,
    horizontal_flip=True,
    fill_mode='nearest'
"""
if apply_data_augmentation:
    img_data_gen = ImageDataGenerator(rotation_range=10,
                                      width_shift_range=10,
                                      height_shift_range=10,
                                      zoom_range=0.3,
                                      horizontal_flip=True,
                                      vertical_flip=True,
                                      fill_mode='reflect')
    mask_data_gen = ImageDataGenerator(rotation_range=10,
                                       width_shift_range=10,
                                       height_shift_range=10,
                                       zoom_range=0.3,
                                       horizontal_flip=True,
                                       vertical_flip=True,
                                       fill_mode='reflect')
else:
    img_data_gen = ImageDataGenerator()
    mask_data_gen = ImageDataGenerator()
# Out:
# " \n    rotation_range=0.2,\n    width_shift_range=0.05,\n    height_shift_range=0.05,\n    shear_range=0.05,\n    zoom_range=0.05,\n    horizontal_flip=True,\n    fill_mode='nearest'\n"

# %%
def read_rgb_mask(img_path):
    '''
    img_path: path to the mask file
    Returns the numpy array containing target values
    '''

    mask_img = Image.open(img_path)
    mask_arr = np.array(mask_img)

    new_mask_arr = np.zeros(mask_arr.shape[:2], dtype=mask_arr.dtype)

    # Use RGB dictionary in 'RGBtoTarget.txt' to convert RGB to target
    new_mask_arr[np.where(np.all(mask_arr == [216, 124, 18], axis=-1))] = 0
    new_mask_arr[np.where(np.all(mask_arr == [255, 255, 255], axis=-1))] = 1
    new_mask_arr[np.where(np.all(mask_arr == [216, 67, 82], axis=-1))] = 2

    return new_mask_arr

# %%
from PIL import Image



class CustomDataset(tf.keras.utils.Sequence):

 

  def __init__(self, dataset_dir, which_subset, img_generator=None, mask_generator=None, 
               preprocessing_function=None, out_shape=[256, 256]):
    if which_subset == 'training':
      subset_file = os.path.join(dataset_dir, 'Splits', 'train.txt')
    elif which_subset == 'validation':
      subset_file = os.path.join(dataset_dir, 'Splits', 'valid.txt')
    
    with open(subset_file, 'r') as f:
      lines = f.readlines()
    
    subset_filenames = []
    for line in lines:
      subset_filenames.append(line.strip()) 

    self.which_subset = which_subset
    self.dataset_dir = dataset_dir
    self.subset_filenames = subset_filenames
    self.img_generator = img_generator
    self.mask_generator = mask_generator
    self.preprocessing_function = preprocessing_function
    self.out_shape = out_shape

  def __len__(self):
    return len(self.subset_filenames)

  def __getitem__(self, index):
    # Read Image
    curr_filename = self.subset_filenames[index]
    img = Image.open(os.path.join(self.dataset_dir, 'Images/', curr_filename + '.png'))
    mask = Image.fromarray(read_rgb_mask(os.path.join(self.dataset_dir, 'Masks/', curr_filename + '.png')))

    # Resize image and mask
    img = img.resize(self.out_shape)
    mask = mask.resize(self.out_shape, resample=Image.NEAREST)
    
    img_arr = np.array(img)
    mask_arr = np.array(mask)



    mask_arr = np.expand_dims(mask_arr, -1)

    if self.which_subset == 'training':
      if self.img_generator is not None and self.mask_generator is not None:
        img_t = self.img_generator.get_random_transform(img_arr.shape, seed=SEED)
        mask_t = self.mask_generator.get_random_transform(mask_arr.shape, seed=SEED)
        img_arr = self.img_generator.apply_transform(img_arr, img_t)
        out_mask = np.zeros_like(mask_arr)
        for c in np.unique(mask_arr):
          if c > 0:
            curr_class_arr = np.float32(mask_arr == c)
            curr_class_arr = self.mask_generator.apply_transform(curr_class_arr, mask_t)
            # from [0, 1] to {0, 1}
            curr_class_arr = np.uint8(curr_class_arr)
            # recover original class
            curr_class_arr = curr_class_arr * c 
            out_mask += curr_class_arr
    else:
      out_mask = mask_arr
    
    if self.preprocessing_function is not None:
        img_arr = self.preprocessing_function(img_arr)

    return img_arr, np.float32(out_mask)

# %%
from os import listdir, makedirs
from os.path import isfile, join, basename, splitext
from random import seed, shuffle

def split_dataset(training_dir, split_dir, training_percentage=0.90):
    """
    Starting from a training directory, creates a split directory
    with two text files, enumerating the images present in the 
    training and the validation set. 
    """

    seed(1234)

    file_names = [f for f in listdir(training_dir) if isfile(join(training_dir, f))]
    shuffle(file_names)

    split = int(len(file_names)*training_percentage)
    train_file_names = "\n".join([splitext(basename(f))[0] for f in file_names[:split]])
    valid_file_names = "\n".join([splitext(basename(f))[0] for f in file_names[split:]])

    makedirs(split_dir)
    with open(join(split_dir, './train.txt'), 'w') as train:
        train.write(train_file_names)
    with open(join(split_dir, './valid.txt'), 'w') as valid:
        valid.write(valid_file_names)



dataset_dir = os.path.join("/content/Development_Dataset/Training/Roseau/Haricot")
split_dataset(join(dataset_dir, 'Images'), join(dataset_dir, 'Splits'))

# %%
from tensorflow.keras.applications.vgg16 import preprocess_input 
import os
img_h = 256
img_w = 256

num_classes = 3
dataset_dir = "/content/Development_Dataset/Training/Roseau/Haricot"


# Set preprocess_input = None to display original image
dataset = CustomDataset(dataset_dir, 'training', 
                        img_generator=img_data_gen, mask_generator=mask_data_gen,
                        preprocessing_function=preprocess_input)
dataset_valid = CustomDataset(dataset_dir, 'validation', 
                              preprocessing_function=preprocess_input)

# %%
bs = 3 # batch size try 3

train_dataset = tf.data.Dataset.from_generator(lambda: dataset,
                                               output_types=(tf.float32, tf.float32),
                                               output_shapes=([img_h, img_w, 3], [img_h, img_w, 1]))

train_dataset = train_dataset.batch(bs)

train_dataset = train_dataset.repeat()

valid_dataset = tf.data.Dataset.from_generator(lambda: dataset_valid,
                                               output_types=(tf.float32, tf.float32),
                                               output_shapes=([img_h, img_w, 3], [img_h, img_w, 1]))
valid_dataset = valid_dataset.batch(bs)

valid_dataset = valid_dataset.repeat()

# %%
# Let's test data generator
# -------------------------
import time
from matplotlib import cm
import matplotlib.pyplot as plt

# %matplotlib inline

# Assign a color to each class
evenly_spaced_interval = np.linspace(0, 1, num_classes)
colors = [cm.rainbow(x) for x in evenly_spaced_interval]

iterator = iter(valid_dataset)

# %%
fig, ax = plt.subplots(1, 2)

augmented_img, target = next(iterator)
augmented_img = augmented_img[0]   # First element
augmented_img = augmented_img  # denormalize

target = np.array(target[0, ..., 0])   # First element (squeezing channel dimension)

print(np.unique(target))

target_img = np.zeros([target.shape[0], target.shape[1], 3])

target_img[np.where(target == 0)] = [0, 0, 0]
for i in range(1, num_classes + 1):
  target_img[np.where(target == i)] = np.array(colors[i-1])[:3] * 255

ax[0].imshow(np.uint8(augmented_img))
ax[1].imshow(np.uint8(target_img))

plt.show()
# Out:
# [0.]

# %%
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPool2D, UpSampling2D, Concatenate
from tensorflow.keras.models import Model

def conv_block(inputs, filters, pool=True):
    x = Conv2D(filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    if pool == True:
        p = MaxPool2D((2, 2))(x)
        return x, p
    else:
        return x

def build_unet(shape, num_classes):
    inputs = Input(shape)

    """ Encoder """
    x1, p1 = conv_block(inputs, 16, pool=True)
    x2, p2 = conv_block(p1, 32, pool=True)
    x3, p3 = conv_block(p2, 48, pool=True)
    x4, p4 = conv_block(p3, 64, pool=True)

    """ Bridge """
    b1 = conv_block(p4, 128, pool=False)

    """ Decoder """
    u1 = UpSampling2D((2, 2), interpolation="bilinear")(b1)
    c1 = Concatenate()([u1, x4])
    x5 = conv_block(c1, 64, pool=False)

    u2 = UpSampling2D((2, 2), interpolation="bilinear")(x5)
    c2 = Concatenate()([u2, x3])
    x6 = conv_block(c2, 48, pool=False)

    u3 = UpSampling2D((2, 2), interpolation="bilinear")(x6)
    c3 = Concatenate()([u3, x2])
    x7 = conv_block(c3, 32, pool=False)

    u4 = UpSampling2D((2, 2), interpolation="bilinear")(x7)
    c4 = Concatenate()([u4, x1])
    x8 = conv_block(c4, 16, pool=False)

    """ Output layer """
    output = Conv2D(num_classes, 1, padding="same", activation="softmax")(x8)

    return Model(inputs, output)

# %%
model = build_unet((256, 256, 3), 3)

# Visualize created model as a table
model.summary()

# Visualize initialized weights
# model.weights
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 256, 256, 16) 448         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 16) 64          conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 256, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 256, 256, 16) 2320        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 16) 64          conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 16) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 128, 128, 32) 4640        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 32) 128         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 128, 128, 32) 9248        activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 32) 128         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 128, 128, 32) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 32)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 64, 64, 48)   13872       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 48)   192         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 64, 48)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 64, 64, 48)   20784       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 48)   192         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 64, 48)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 48)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 32, 32, 64)   27712       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 64)   256         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 32, 32, 64)   36928       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 64)   256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 64)   0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 16, 16, 128)  73856       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 128)  512         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 16, 16, 128)  147584      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 128)  512         conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16, 16, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 32, 32, 128)  0           activation_9[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 192)  0           up_sampling2d_4[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 32, 32, 64)   110656      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 64)   256         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 64)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 32, 32, 64)   36928       activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 64)   256         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 32, 32, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 64, 64, 64)   0           activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 112)  0           up_sampling2d_5[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 64, 64, 48)   48432       concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 64, 48)   192         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 64, 64, 48)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 64, 64, 48)   20784       activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 64, 48)   192         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 64, 64, 48)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 128, 128, 48) 0           activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 80) 0           up_sampling2d_6[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 128, 128, 32) 23072       concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 128, 128, 32) 128         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 128, 128, 32) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 128, 128, 32) 9248        activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 128, 128, 32) 128         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 128, 128, 32) 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 256, 256, 32) 0           activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 48) 0           up_sampling2d_7[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 256, 256, 16) 6928        concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 256, 256, 16) 64          conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 256, 256, 16) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 256, 256, 16) 2320        activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 256, 256, 16) 64          conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 256, 256, 16) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 256, 256, 3)  51          activation_17[0][0]
# ==================================================================================================
# Total params: 599,395
# Trainable params: 597,603
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %% [markdown]
# ## Prepare the model for training

# %%
# Optimization params

# Loss
# Sparse Categorical Crossentropy to use integers (mask) instead of one-hot encoded labels
loss = tf.keras.losses.SparseCategoricalCrossentropy() 
# learning rate
lr = 1e-4
optimizer = tf.keras.optimizers.Adam(learning_rate=lr)

# Here we define the intersection over union for each class in the batch.
# Then we compute the final iou as the mean over classes
def meanIoU(y_true, y_pred):
    # get predicted class from softmax
    y_pred = tf.expand_dims(tf.argmax(y_pred, -1), -1)

    per_class_iou = []

    for i in range(1, num_classes): # exclude the background class 0
      # Get prediction and target related to only a single class (i)
      class_pred = tf.cast(tf.where(y_pred == i, 1, 0), tf.float32)
      class_true = tf.cast(tf.where(y_true == i, 1, 0), tf.float32)
      intersection = tf.reduce_sum(class_true * class_pred)
      union = tf.reduce_sum(class_true) + tf.reduce_sum(class_pred) - intersection
    
      iou = (intersection + 1e-7) / (union + 1e-7)
      per_class_iou.append(iou)

    return tf.reduce_mean(per_class_iou)

# Validation metrics
metrics = ['accuracy', meanIoU]
# Compile Model
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

# %% [markdown]
# ## Training with callbacks

# %%
import os
from datetime import datetime

cwd = os.getcwd()

exps_dir = os.path.join(cwd, 'drive/My Drive/Keras4/', 'unet')
if not os.path.exists(exps_dir):
    os.makedirs(exps_dir)

now = datetime.now().strftime('%b%d_%H-%M-%S')

model_name = 'unet'

exp_dir = os.path.join(exps_dir, model_name + '_' + str(now))
if not os.path.exists(exp_dir):
    os.makedirs(exp_dir)
    
callbacks = []

# Model checkpoint
# ----------------
ckpt_dir = os.path.join(exp_dir, 'ckpts')
if not os.path.exists(ckpt_dir):
    os.makedirs(ckpt_dir)

ckpt_callback = tf.keras.callbacks.ModelCheckpoint(filepath=os.path.join(ckpt_dir, 'cp_{epoch:02d}.ckpt'), 
                                                   save_weights_only=True)  # False to save the model directly
callbacks.append(ckpt_callback)

# Visualize Learning on Tensorboard
# ---------------------------------
tb_dir = os.path.join(exp_dir, 'tb_logs')
if not os.path.exists(tb_dir):
    os.makedirs(tb_dir)
    
# By default shows losses and metrics for both training and validation
tb_callback = tf.keras.callbacks.TensorBoard(log_dir=tb_dir,
                                             profile_batch=0,
                                             histogram_freq=0)  # if 1 shows weights histograms
callbacks.append(tb_callback)

# Early Stopping
# --------------
early_stop = True
if early_stop:
    es_callback = tf.keras.callback.EarlyStopping(monitor='val_loss', patience=6)
    callbacks.append(es_callback)




# How to visualize Tensorboard

# 1. tensorboard --logdir EXPERIMENTS_DIR --port PORT     <- from terminal
# 2. localhost:PORT   <- in your browser

# %%
model.fit(x=train_dataset,
          epochs=100,  #### set repeat in training dataset
          steps_per_epoch=len(dataset),
          validation_data=valid_dataset,
          validation_steps=len(dataset_valid), 
          callbacks=callbacks)
# Out:
# Epoch 1/100
# 81/81 [==============================] - 43s 526ms/step - loss: 1.1807 - accuracy: 0.4564 - meanIoU: 0.0679 - val_loss: 1.2795 - val_accuracy: 0.1309 - val_meanIoU: 0.0379
# Epoch 2/100
# 81/81 [==============================] - 42s 519ms/step - loss: 0.8227 - accuracy: 0.8588 - meanIoU: 0.1495 - val_loss: 0.9410 - val_accuracy: 0.7027 - val_meanIoU: 0.0565
# Epoch 3/100
# 81/81 [==============================] - 42s 522ms/step - loss: 0.7146 - accuracy: 0.9065 - meanIoU: 0.2220 - val_loss: 0.7925 - val_accuracy: 0.8361 - val_meanIoU: 0.1329
# Epoch 4/100
# 81/81 [==============================] - 42s 519ms/step - loss: 0.6596 - accuracy: 0.9226 - meanIoU: 0.2777 - val_loss: 0.7269 - val_accuracy: 0.8397 - val_meanIoU: 0.1736
# Epoch 5/100
# 81/81 [==============================] - 42s 524ms/step - loss: 0.6179 - accuracy: 0.9301 - meanIoU: 0.3109 - val_loss: 0.6680 - val_accuracy: 0.8533 - val_meanIoU: 0.1874
# Epoch 6/100
# 81/81 [==============================] - 42s 524ms/step - loss: 0.5819 - accuracy: 0.9351 - meanIoU: 0.3330 - val_loss: 0.5854 - val_accuracy: 0.9180 - val_meanIoU: 0.2521
# Epoch 7/100
# 81/81 [==============================] - 42s 520ms/step - loss: 0.5563 - accuracy: 0.9353 - meanIoU: 0.3371 - val_loss: 0.5607 - val_accuracy: 0.9058 - val_meanIoU: 0.2003
# Epoch 8/100
# 81/81 [==============================] - 42s 522ms/step - loss: 0.5129 - accuracy: 0.9406 - meanIoU: 0.3687 - val_loss: 0.5265 - val_accuracy: 0.9164 - val_meanIoU: 0.1987
# Epoch 9/100
# 81/81 [==============================] - 42s 522ms/step - loss: 0.4766 - accuracy: 0.9453 - meanIoU: 0.4058 - val_loss: 0.4916 - val_accuracy: 0.9202 - val_meanIoU: 0.1928
# Epoch 10/100
# 81/81 [==============================] - 42s 524ms/step - loss: 0.4406 - accuracy: 0.9493 - meanIoU: 0.4395 - val_loss: 0.4633 - val_accuracy: 0.9250 - val_meanIoU: 0.2109
# Epoch 11/100
# 81/81 [==============================] - 42s 522ms/step - loss: 0.4088 - accuracy: 0.9526 - meanIoU: 0.4687 - val_loss: 0.4768 - val_accuracy: 0.8971 - val_meanIoU: 0.1867
# Epoch 12/100
# 81/81 [==============================] - 42s 522ms/step - loss: 0.3843 - accuracy: 0.9532 - meanIoU: 0.4725 - val_loss: 0.4211 - val_accuracy: 0.9252 - val_meanIoU: 0.2245
# Epoch 13/100
# 81/81 [==============================] - 43s 526ms/step - loss: 0.3583 - accuracy: 0.9556 - meanIoU: 0.4976 - val_loss: 0.4139 - val_accuracy: 0.9168 - val_meanIoU: 0.1986
# Epoch 14/100
# 81/81 [==============================] - 42s 519ms/step - loss: 0.3352 - accuracy: 0.9573 - meanIoU: 0.5145 - val_loss: 0.3942 - val_accuracy: 0.9223 - val_meanIoU: 0.2100
# Epoch 15/100
# 81/81 [==============================] - 42s 524ms/step - loss: 0.3198 - accuracy: 0.9563 - meanIoU: 0.5000 - val_loss: 0.4299 - val_accuracy: 0.8853 - val_meanIoU: 0.1778
# Epoch 16/100
# 81/81 [==============================] - 42s 522ms/step - loss: 0.3005 - accuracy: 0.9577 - meanIoU: 0.5128 - val_loss: 0.3404 - val_accuracy: 0.9297 - val_meanIoU: 0.2390
# Epoch 17/100
# 81/81 [==============================] - 43s 528ms/step - loss: 0.2771 - accuracy: 0.9617 - meanIoU: 0.5592 - val_loss: 0.3331 - val_accuracy: 0.9316 - val_meanIoU: 0.2356
# Epoch 18/100
# 81/81 [==============================] - 43s 530ms/step - loss: 0.2603 - accuracy: 0.9634 - meanIoU: 0.5779 - val_loss: 0.3347 - val_accuracy: 0.9248 - val_meanIoU: 0.2202
# Epoch 19/100
# 81/81 [==============================] - 43s 529ms/step - loss: 0.2469 - accuracy: 0.9637 - meanIoU: 0.5836 - val_loss: 0.3472 - val_accuracy: 0.9099 - val_meanIoU: 0.2032
# Epoch 20/100
# 81/81 [==============================] - 43s 536ms/step - loss: 0.2368 - accuracy: 0.9629 - meanIoU: 0.5759 - val_loss: 0.3239 - val_accuracy: 0.9219 - val_meanIoU: 0.2179
# Epoch 21/100
# 81/81 [==============================] - 44s 539ms/step - loss: 0.2261 - accuracy: 0.9629 - meanIoU: 0.5729 - val_loss: 0.2965 - val_accuracy: 0.9290 - val_meanIoU: 0.2348
# Epoch 22/100
# 81/81 [==============================] - 46s 565ms/step - loss: 0.2117 - accuracy: 0.9653 - meanIoU: 0.6015 - val_loss: 0.3026 - val_accuracy: 0.9264 - val_meanIoU: 0.2019
# Epoch 23/100
# 81/81 [==============================] - 44s 541ms/step - loss: 0.2006 - accuracy: 0.9664 - meanIoU: 0.6148 - val_loss: 0.2837 - val_accuracy: 0.9268 - val_meanIoU: 0.2326
# Epoch 24/100
# 81/81 [==============================] - 45s 551ms/step - loss: 0.1926 - accuracy: 0.9661 - meanIoU: 0.6113 - val_loss: 0.2781 - val_accuracy: 0.9282 - val_meanIoU: 0.2352
# Epoch 25/100
# 81/81 [==============================] - 44s 538ms/step - loss: 0.1835 - accuracy: 0.9668 - meanIoU: 0.6220 - val_loss: 0.2929 - val_accuracy: 0.9261 - val_meanIoU: 0.2229
# Epoch 26/100
# 81/81 [==============================] - 44s 547ms/step - loss: 0.1733 - accuracy: 0.9683 - meanIoU: 0.6397 - val_loss: 0.2802 - val_accuracy: 0.9235 - val_meanIoU: 0.2086
# Epoch 27/100
# 81/81 [==============================] - 45s 552ms/step - loss: 0.1654 - accuracy: 0.9688 - meanIoU: 0.6464 - val_loss: 0.2658 - val_accuracy: 0.9278 - val_meanIoU: 0.2189
# Epoch 28/100
# 81/81 [==============================] - 45s 552ms/step - loss: 0.1604 - accuracy: 0.9684 - meanIoU: 0.6417 - val_loss: 0.2720 - val_accuracy: 0.9252 - val_meanIoU: 0.2044
# Epoch 29/100
# 81/81 [==============================] - 45s 556ms/step - loss: 0.1555 - accuracy: 0.9680 - meanIoU: 0.6366 - val_loss: 0.3016 - val_accuracy: 0.9060 - val_meanIoU: 0.2181
# Epoch 30/100
# 81/81 [==============================] - 44s 549ms/step - loss: 0.1502 - accuracy: 0.9682 - meanIoU: 0.6365 - val_loss: 0.2824 - val_accuracy: 0.9243 - val_meanIoU: 0.1933
# Epoch 31/100
# 81/81 [==============================] - 44s 541ms/step - loss: 0.1455 - accuracy: 0.9684 - meanIoU: 0.6382 - val_loss: 0.2599 - val_accuracy: 0.9259 - val_meanIoU: 0.2202
# Epoch 32/100
# 81/81 [==============================] - 44s 545ms/step - loss: 0.1386 - accuracy: 0.9694 - meanIoU: 0.6500 - val_loss: 0.2577 - val_accuracy: 0.9299 - val_meanIoU: 0.2248
# Epoch 33/100
# 81/81 [==============================] - 44s 545ms/step - loss: 0.1306 - accuracy: 0.9711 - meanIoU: 0.6718 - val_loss: 0.2425 - val_accuracy: 0.9325 - val_meanIoU: 0.2620
# Epoch 34/100
# 81/81 [==============================] - 44s 540ms/step - loss: 0.1252 - accuracy: 0.9717 - meanIoU: 0.6772 - val_loss: 0.2668 - val_accuracy: 0.9247 - val_meanIoU: 0.2027
# Epoch 35/100
# 81/81 [==============================] - 44s 538ms/step - loss: 0.1213 - accuracy: 0.9717 - meanIoU: 0.6781 - val_loss: 0.2715 - val_accuracy: 0.9217 - val_meanIoU: 0.2067
# Epoch 36/100
# 81/81 [==============================] - 44s 537ms/step - loss: 0.1193 - accuracy: 0.9713 - meanIoU: 0.6693 - val_loss: 0.2853 - val_accuracy: 0.9187 - val_meanIoU: 0.2170
# Epoch 37/100
# 81/81 [==============================] - 44s 543ms/step - loss: 0.1160 - accuracy: 0.9714 - meanIoU: 0.6714 - val_loss: 0.2539 - val_accuracy: 0.9280 - val_meanIoU: 0.2122
# Epoch 38/100
# 81/81 [==============================] - 44s 548ms/step - loss: 0.1122 - accuracy: 0.9719 - meanIoU: 0.6742 - val_loss: 0.2569 - val_accuracy: 0.9277 - val_meanIoU: 0.2368
# Epoch 39/100
# 81/81 [==============================] - 45s 554ms/step - loss: 0.1100 - accuracy: 0.9717 - meanIoU: 0.6724 - val_loss: 0.2655 - val_accuracy: 0.9256 - val_meanIoU: 0.2142
# Epoch 40/100
# 81/81 [==============================] - 44s 548ms/step - loss: 0.1050 - accuracy: 0.9728 - meanIoU: 0.6835 - val_loss: 0.2615 - val_accuracy: 0.9253 - val_meanIoU: 0.2407
# Epoch 41/100
# 81/81 [==============================] - 45s 556ms/step - loss: 0.1006 - accuracy: 0.9736 - meanIoU: 0.6969 - val_loss: 0.2468 - val_accuracy: 0.9291 - val_meanIoU: 0.2254
# Epoch 42/100
# 81/81 [==============================] - 45s 552ms/step - loss: 0.0962 - accuracy: 0.9746 - meanIoU: 0.7089 - val_loss: 0.2535 - val_accuracy: 0.9285 - val_meanIoU: 0.2266
# Epoch 43/100
# 81/81 [==============================] - 45s 550ms/step - loss: 0.0924 - accuracy: 0.9753 - meanIoU: 0.7168 - val_loss: 0.2542 - val_accuracy: 0.9278 - val_meanIoU: 0.2341
# Epoch 44/100
# 81/81 [==============================] - 45s 555ms/step - loss: 0.0905 - accuracy: 0.9753 - meanIoU: 0.7164 - val_loss: 0.2598 - val_accuracy: 0.9268 - val_meanIoU: 0.2187
# Epoch 45/100
# 81/81 [==============================] - 45s 551ms/step - loss: 0.0887 - accuracy: 0.9753 - meanIoU: 0.7168 - val_loss: 0.2643 - val_accuracy: 0.9230 - val_meanIoU: 0.2303
# Epoch 46/100
# 81/81 [==============================] - 45s 558ms/step - loss: 0.0861 - accuracy: 0.9757 - meanIoU: 0.7212 - val_loss: 0.3127 - val_accuracy: 0.9115 - val_meanIoU: 0.1545
# Epoch 47/100
# 81/81 [==============================] - 46s 565ms/step - loss: 0.0860 - accuracy: 0.9751 - meanIoU: 0.7153 - val_loss: 0.2746 - val_accuracy: 0.9229 - val_meanIoU: 0.2122
# Epoch 48/100
# 81/81 [==============================] - 46s 562ms/step - loss: 0.0867 - accuracy: 0.9741 - meanIoU: 0.7032 - val_loss: 0.2551 - val_accuracy: 0.9282 - val_meanIoU: 0.2412
# Epoch 49/100
# 81/81 [==============================] - 45s 557ms/step - loss: 0.0823 - accuracy: 0.9754 - meanIoU: 0.7165 - val_loss: 0.2526 - val_accuracy: 0.9292 - val_meanIoU: 0.2353
# Epoch 50/100
# 81/81 [==============================] - 46s 562ms/step - loss: 0.0796 - accuracy: 0.9761 - meanIoU: 0.7222 - val_loss: 0.3106 - val_accuracy: 0.9151 - val_meanIoU: 0.1680
# Epoch 51/100
# 81/81 [==============================] - 46s 567ms/step - loss: 0.0790 - accuracy: 0.9758 - meanIoU: 0.7201 - val_loss: 0.2754 - val_accuracy: 0.9255 - val_meanIoU: 0.2042
# Epoch 52/100
# 81/81 [==============================] - 45s 558ms/step - loss: 0.0773 - accuracy: 0.9760 - meanIoU: 0.7224 - val_loss: 0.2713 - val_accuracy: 0.9253 - val_meanIoU: 0.2183
# Epoch 53/100
# 81/81 [==============================] - 45s 561ms/step - loss: 0.0744 - accuracy: 0.9768 - meanIoU: 0.7311 - val_loss: 0.2782 - val_accuracy: 0.9214 - val_meanIoU: 0.1796
# Epoch 54/100
# 81/81 [==============================] - 46s 563ms/step - loss: 0.0724 - accuracy: 0.9772 - meanIoU: 0.7375 - val_loss: 0.2733 - val_accuracy: 0.9243 - val_meanIoU: 0.2105
# Epoch 55/100
# 81/81 [==============================] - 45s 555ms/step - loss: 0.0713 - accuracy: 0.9773 - meanIoU: 0.7352 - val_loss: 0.3145 - val_accuracy: 0.9189 - val_meanIoU: 0.2033
# Epoch 56/100
# 81/81 [==============================] - 45s 555ms/step - loss: 0.0696 - accuracy: 0.9777 - meanIoU: 0.7383 - val_loss: 0.2864 - val_accuracy: 0.9237 - val_meanIoU: 0.1857
# Epoch 57/100
# 81/81 [==============================] - 45s 557ms/step - loss: 0.0668 - accuracy: 0.9785 - meanIoU: 0.7498 - val_loss: 0.2810 - val_accuracy: 0.9234 - val_meanIoU: 0.2065
# Epoch 58/100
# 81/81 [==============================] - 46s 562ms/step - loss: 0.0645 - accuracy: 0.9791 - meanIoU: 0.7561 - val_loss: 0.2572 - val_accuracy: 0.9313 - val_meanIoU: 0.2499
# Epoch 59/100
# 81/81 [==============================] - 46s 563ms/step - loss: 0.0642 - accuracy: 0.9789 - meanIoU: 0.7542 - val_loss: 0.2789 - val_accuracy: 0.9265 - val_meanIoU: 0.2199
# Epoch 60/100
# 81/81 [==============================] - 46s 567ms/step - loss: 0.0640 - accuracy: 0.9787 - meanIoU: 0.7519 - val_loss: 0.2867 - val_accuracy: 0.9237 - val_meanIoU: 0.2090
# Epoch 61/100
# 81/81 [==============================] - 46s 574ms/step - loss: 0.0634 - accuracy: 0.9786 - meanIoU: 0.7508 - val_loss: 0.3082 - val_accuracy: 0.9177 - val_meanIoU: 0.1998
# Epoch 62/100
# 81/81 [==============================] - 46s 567ms/step - loss: 0.0644 - accuracy: 0.9779 - meanIoU: 0.7425 - val_loss: 0.2756 - val_accuracy: 0.9250 - val_meanIoU: 0.2424
# Epoch 63/100
# 81/81 [==============================] - 46s 564ms/step - loss: 0.0631 - accuracy: 0.9783 - meanIoU: 0.7414 - val_loss: 0.2847 - val_accuracy: 0.9257 - val_meanIoU: 0.2352
# Epoch 64/100
# 81/81 [==============================] - 46s 564ms/step - loss: 0.0605 - accuracy: 0.9791 - meanIoU: 0.7503 - val_loss: 0.2953 - val_accuracy: 0.9263 - val_meanIoU: 0.2121
# Epoch 65/100
# 81/81 [==============================] - 46s 563ms/step - loss: 0.0589 - accuracy: 0.9795 - meanIoU: 0.7578 - val_loss: 0.3124 - val_accuracy: 0.9213 - val_meanIoU: 0.1864
# Epoch 66/100
# 81/81 [==============================] - 45s 557ms/step - loss: 0.0579 - accuracy: 0.9798 - meanIoU: 0.7615 - val_loss: 0.2839 - val_accuracy: 0.9259 - val_meanIoU: 0.2187
# Epoch 67/100
# 81/81 [==============================] - 46s 563ms/step - loss: 0.0571 - accuracy: 0.9799 - meanIoU: 0.7598 - val_loss: 0.2996 - val_accuracy: 0.9230 - val_meanIoU: 0.2074
# Epoch 68/100
# 81/81 [==============================] - 45s 561ms/step - loss: 0.0575 - accuracy: 0.9795 - meanIoU: 0.7574 - val_loss: 0.3105 - val_accuracy: 0.9202 - val_meanIoU: 0.1720
# Epoch 69/100
# 81/81 [==============================] - 46s 564ms/step - loss: 0.0576 - accuracy: 0.9793 - meanIoU: 0.7569 - val_loss: 0.2833 - val_accuracy: 0.9239 - val_meanIoU: 0.2373
# Epoch 70/100
# 81/81 [==============================] - 46s 569ms/step - loss: 0.0535 - accuracy: 0.9809 - meanIoU: 0.7768 - val_loss: 0.2799 - val_accuracy: 0.9272 - val_meanIoU: 0.2327
# Epoch 71/100
# 81/81 [==============================] - 46s 568ms/step - loss: 0.0515 - accuracy: 0.9816 - meanIoU: 0.7831 - val_loss: 0.2961 - val_accuracy: 0.9227 - val_meanIoU: 0.2127
# Epoch 72/100
# 81/81 [==============================] - 46s 567ms/step - loss: 0.0523 - accuracy: 0.9811 - meanIoU: 0.7747 - val_loss: 0.3013 - val_accuracy: 0.9219 - val_meanIoU: 0.2269
# Epoch 73/100
# 81/81 [==============================] - 46s 568ms/step - loss: 0.0540 - accuracy: 0.9801 - meanIoU: 0.7649 - val_loss: 0.2907 - val_accuracy: 0.9263 - val_meanIoU: 0.2497
# Epoch 74/100
# 81/81 [==============================] - 47s 575ms/step - loss: 0.0521 - accuracy: 0.9808 - meanIoU: 0.7738 - val_loss: 0.3037 - val_accuracy: 0.9242 - val_meanIoU: 0.2178
# Epoch 75/100
# 81/81 [==============================] - 46s 569ms/step - loss: 0.0505 - accuracy: 0.9814 - meanIoU: 0.7818 - val_loss: 0.3186 - val_accuracy: 0.9227 - val_meanIoU: 0.2026
# Epoch 76/100
# 81/81 [==============================] - 46s 573ms/step - loss: 0.0511 - accuracy: 0.9810 - meanIoU: 0.7760 - val_loss: 0.2952 - val_accuracy: 0.9268 - val_meanIoU: 0.2269
# Epoch 77/100
# 81/81 [==============================] - 47s 576ms/step - loss: 0.0518 - accuracy: 0.9806 - meanIoU: 0.7702 - val_loss: 0.3131 - val_accuracy: 0.9250 - val_meanIoU: 0.2125
# Epoch 78/100
# 81/81 [==============================] - 46s 574ms/step - loss: 0.0505 - accuracy: 0.9809 - meanIoU: 0.7736 - val_loss: 0.3067 - val_accuracy: 0.9251 - val_meanIoU: 0.2077
# Epoch 79/100
# 81/81 [==============================] - 46s 570ms/step - loss: 0.0480 - accuracy: 0.9819 - meanIoU: 0.7883 - val_loss: 0.3003 - val_accuracy: 0.9248 - val_meanIoU: 0.2213
# Epoch 80/100
# 81/81 [==============================] - 46s 569ms/step - loss: 0.0466 - accuracy: 0.9824 - meanIoU: 0.7938 - val_loss: 0.3666 - val_accuracy: 0.9075 - val_meanIoU: 0.1758
# Epoch 81/100
# 81/81 [==============================] - 46s 569ms/step - loss: 0.0466 - accuracy: 0.9822 - meanIoU: 0.7918 - val_loss: 0.3454 - val_accuracy: 0.9110 - val_meanIoU: 0.2123
# Epoch 82/100
# 81/81 [==============================] - 45s 560ms/step - loss: 0.0486 - accuracy: 0.9813 - meanIoU: 0.7774 - val_loss: 0.3185 - val_accuracy: 0.9256 - val_meanIoU: 0.2332
# Epoch 83/100
# 81/81 [==============================] - 45s 561ms/step - loss: 0.0484 - accuracy: 0.9812 - meanIoU: 0.7769 - val_loss: 0.3181 - val_accuracy: 0.9247 - val_meanIoU: 0.2062
# Epoch 84/100
# 81/81 [==============================] - 45s 561ms/step - loss: 0.0474 - accuracy: 0.9815 - meanIoU: 0.7818 - val_loss: 0.3159 - val_accuracy: 0.9252 - val_meanIoU: 0.2240
# Epoch 85/100
# 81/81 [==============================] - 45s 556ms/step - loss: 0.0454 - accuracy: 0.9824 - meanIoU: 0.7921 - val_loss: 0.3671 - val_accuracy: 0.9173 - val_meanIoU: 0.1788
# Epoch 86/100
# 81/81 [==============================] - 46s 563ms/step - loss: 0.0429 - accuracy: 0.9835 - meanIoU: 0.8046 - val_loss: 0.3111 - val_accuracy: 0.9269 - val_meanIoU: 0.2386
# Epoch 87/100
# 81/81 [==============================] - 45s 557ms/step - loss: 0.0409 - accuracy: 0.9843 - meanIoU: 0.8127 - val_loss: 0.3085 - val_accuracy: 0.9270 - val_meanIoU: 0.2240
# Epoch 88/100
# 81/81 [==============================] - 45s 560ms/step - loss: 0.0409 - accuracy: 0.9842 - meanIoU: 0.8118 - val_loss: 0.3339 - val_accuracy: 0.9192 - val_meanIoU: 0.2157
# Epoch 89/100
# 81/81 [==============================] - 45s 560ms/step - loss: 0.0414 - accuracy: 0.9839 - meanIoU: 0.8084 - val_loss: 0.3187 - val_accuracy: 0.9232 - val_meanIoU: 0.2394
# Epoch 90/100
# 81/81 [==============================] - 46s 566ms/step - loss: 0.0426 - accuracy: 0.9833 - meanIoU: 0.8029 - val_loss: 0.3290 - val_accuracy: 0.9254 - val_meanIoU: 0.2240
# Epoch 91/100
# 81/81 [==============================] - 46s 570ms/step - loss: 0.0431 - accuracy: 0.9830 - meanIoU: 0.7978 - val_loss: 0.3058 - val_accuracy: 0.9302 - val_meanIoU: 0.2498
# Epoch 92/100
# 81/81 [==============================] - 46s 567ms/step - loss: 0.0420 - accuracy: 0.9834 - meanIoU: 0.8015 - val_loss: 0.3580 - val_accuracy: 0.9198 - val_meanIoU: 0.1910
# Epoch 93/100
# 81/81 [==============================] - 46s 570ms/step - loss: 0.0396 - accuracy: 0.9845 - meanIoU: 0.8134 - val_loss: 0.3200 - val_accuracy: 0.9260 - val_meanIoU: 0.2382
# Epoch 94/100
# 81/81 [==============================] - 46s 568ms/step - loss: 0.0383 - accuracy: 0.9850 - meanIoU: 0.8188 - val_loss: 0.3483 - val_accuracy: 0.9216 - val_meanIoU: 0.2150
# Epoch 95/100
# 81/81 [==============================] - 46s 566ms/step - loss: 0.0380 - accuracy: 0.9851 - meanIoU: 0.8199 - val_loss: 0.3607 - val_accuracy: 0.9224 - val_meanIoU: 0.1927
# Epoch 96/100
# 81/81 [==============================] - 46s 565ms/step - loss: 0.0385 - accuracy: 0.9848 - meanIoU: 0.8164 - val_loss: 0.3338 - val_accuracy: 0.9268 - val_meanIoU: 0.2269
# Epoch 97/100
# 81/81 [==============================] - 46s 562ms/step - loss: 0.0397 - accuracy: 0.9841 - meanIoU: 0.8096 - val_loss: 0.3518 - val_accuracy: 0.9241 - val_meanIoU: 0.2220
# Epoch 98/100
# 81/81 [==============================] - 46s 562ms/step - loss: 0.0404 - accuracy: 0.9838 - meanIoU: 0.8059 - val_loss: 0.3631 - val_accuracy: 0.9212 - val_meanIoU: 0.1961
# Epoch 99/100
# 81/81 [==============================] - 45s 557ms/step - loss: 0.0402 - accuracy: 0.9839 - meanIoU: 0.8081 - val_loss: 0.3570 - val_accuracy: 0.9235 - val_meanIoU: 0.2358
# Epoch 100/100
# 81/81 [==============================] - 45s 557ms/step - loss: 0.0402 - accuracy: 0.9838 - meanIoU: 0.8076 - val_loss: 0.3482 - val_accuracy: 0.9203 - val_meanIoU: 0.2409

# %% [markdown]
# ## Test model

# %% [markdown]
# ## Compute prediction

# %%
model.save('/content/drive/MyDrive/model_baseline_roseau_unet.h5')

# %%
model = tf.keras.models.load_model('model_baseline_roseau_unet.h5', {'meanIoU': meanIoU})

# %%
iterator = iter(valid_dataset)

# %%
# Show original, correct, predicted (validation)

fig, ax = plt.subplots(1, 3, figsize=(8, 8))
fig.show()
image, target = next(iterator)
print(type(image))
image = image[0]
target = target[0, ..., 0]

out_sigmoid = model.predict(x=tf.expand_dims(image, 0))

predicted_class = tf.argmax(out_sigmoid, -1)

out_sigmoid.shape

predicted_class = predicted_class[0, ...] #256*256
predicted_class.shape

# Assign colors (just for visualization)
target_img = np.zeros([target.shape[0], target.shape[1], 3])
prediction_img = np.zeros([target.shape[0], target.shape[1], 3])

target_img[np.where(target == 0)] = [0, 0, 0]
for i in range(1, num_classes):
  target_img[np.where(target == i)] = np.array(colors[i-1])[:3] * 255

prediction_img[np.where(predicted_class == 0)] = [0, 0, 0]
for i in range(1, num_classes):
  prediction_img[np.where(predicted_class == i)] = np.array(colors[i-1])[:3] * 255

ax[0].imshow(np.uint8(image))
ax[1].imshow(np.uint8(target_img))
ax[2].imshow(np.uint8(prediction_img))

fig.canvas.draw()
# Out:
# <class 'tensorflow.python.framework.ops.EagerTensor'>
# (1, 256, 256, 3)
# TensorShape([256, 256])

# %%
# Compute predictions

from os import listdir
from os.path import isfile, join, basename, splitext

# CustomTestDataset to load test images
# Specify the full path to the folder containing the images
class CustomTestDataset(tf.keras.utils.Sequence):

    def __init__(self, dataset_dir, img_generator=None, 
              preprocessing_function=None, out_shape=[img_h, img_w]):

      subset_filenames = [splitext(basename(f))[0] for f in 
                                                listdir(dataset_dir) if isfile(join(dataset_dir, f))]

      self.dataset_dir = dataset_dir
      self.subset_filenames = subset_filenames
      self.img_generator = img_generator
      self.preprocessing_function = preprocessing_function
      self.out_shape = out_shape


    def __len__(self):
        return len(self.subset_filenames)


    def get_original_size(self, index):
        curr_filename = self.subset_filenames[index]
        img = Image.open(os.path.join(self.dataset_dir, curr_filename + '.png'))
        width, height = img.size

        return [height, width]


    def __getitem__(self, index):
        # Read Image
        curr_filename = self.subset_filenames[index]
        img = Image.open(os.path.join(self.dataset_dir, curr_filename + '.png'))

        # Resize image and mask
        img = img.resize(self.out_shape)
        img_arr = np.array(img)

        if self.preprocessing_function is not None:
            img_arr = self.preprocessing_function(img_arr)

        return img_arr


    def get_name(self, index):
        return self.subset_filenames[index]

# %%
import json
from prepare_submission import rle_encode
test_dir = '/content/Development_Dataset/Test_Dev/Roseau/Haricot/Images'


test_dataset = CustomTestDataset(test_dir, preprocessing_function=preprocess_input)

submission_dict = {}

for i in range(test_dataset.__len__()):
    image = test_dataset.__getitem__(i)
    img_name = test_dataset.get_name(i)
    original_h, original_w = test_dataset.get_original_size(i)

    prediction = model.predict(tf.expand_dims(image, axis=0))
    mask_arr = tf.argmax(prediction, -1)[0, ...] # (256, 256)
    mask_arr = tf.expand_dims(mask_arr, axis=2)
    print(mask_arr.shape)
    mask_arr = tf.image.resize(mask_arr, (original_h, original_w),                          
                                method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)

    mask_arr = np.array(mask_arr)

    submission_dict[img_name] = {}
    submission_dict[img_name]['shape'] = [original_h, original_w]
    submission_dict[img_name]['team'] = 'Roseau'
    submission_dict[img_name]['crop'] = 'Haricot'
    submission_dict[img_name]['segmentation'] = {}

    rle_encoded_crop = rle_encode(mask_arr == 1)
    rle_encoded_weed = rle_encode(mask_arr == 2)

    submission_dict[img_name]['segmentation']['crop'] = rle_encoded_crop
    submission_dict[img_name]['segmentation']['weed'] = rle_encoded_weed
# Out:
# (256, 256, 1)
# (256, 256, 1)
# (256, 256, 1)
# (256, 256, 1)
# (256, 256, 1)
# (256, 256, 1)
# (256, 256, 1)
# (256, 256, 1)
# (256, 256, 1)
# (256, 256, 1)
# (256, 256, 1)
# (256, 256, 1)
# (256, 256, 1)
# (256, 256, 1)
# (256, 256, 1)

# %%
# empty submission for other datasets
def empty_submission(team, crop, dir):
    images_dir = join(dir, team, crop, 'Images')
    images_name = [splitext(basename(f))[0] for f in listdir(images_dir) if isfile(join(images_dir, f))]
    
    res = {}
    for img_name in images_name:
        res[img_name] = {}
        res[img_name]['shape'] = [256, 256] # non importa molto la shape per le submission vuote
        res[img_name]['team'] = team
        res[img_name]['crop'] = crop
        res[img_name]['segmentation'] = {}
        res[img_name]['segmentation']['crop'] = ""
        res[img_name]['segmentation']['weed'] = ""

    return res

dir = r'/content/Development_Dataset/Test_Dev'
submission_dict.update(empty_submission('Bipbip', 'Haricot', dir))
submission_dict.update(empty_submission('Bipbip', 'Mais', dir))
submission_dict.update(empty_submission('Pead', 'Haricot', dir))
submission_dict.update(empty_submission('Pead', 'Mais', dir))
submission_dict.update(empty_submission('Roseau', 'Mais', dir))
submission_dict.update(empty_submission('Weedelec', 'Haricot', dir))
submission_dict.update(empty_submission('Weedelec', 'Mais', dir))

with open('./submission.json', 'w') as f:
    json.dump(submission_dict, f)

# %%
# Show original, predicted (test)

test_dataset = CustomTestDataset(test_dir, preprocessing_function=preprocess_input)
test_iter = iter(test_dataset)

# %%
# Show original, predicted (test)
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2, figsize=(8, 8))
fig.show()

image = next(test_iter)

out_sigmoid = model.predict(x=tf.expand_dims(image, 0))

predicted_class = tf.argmax(out_sigmoid, -1)[0, ...]
print(np.unique(np.array(predicted_class)))

# Assign colors (just for visualization)
prediction_img = np.zeros([image.shape[0], image.shape[1], 3])

prediction_img[np.where(predicted_class == 0)] = [0, 0, 0]
for i in range(1, num_classes+1):
  prediction_img[np.where(predicted_class == i)] = np.array(colors[i-1])[:3] * 255

ax[0].imshow(np.uint8(image))
ax[1].imshow(np.uint8(prediction_img))

fig.canvas.draw()
# Out:
# [0 1 2]
